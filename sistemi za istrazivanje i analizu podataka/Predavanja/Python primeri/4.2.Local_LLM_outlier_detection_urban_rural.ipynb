# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %%
from langchain_community.llms import Ollama
import pandasai as pai
from pandasai import Agent

# %%
pai.clear_cache()

# %%
llm = Ollama(model="llama3.2")

# %%
df = pd.read_csv('responses.csv')

# %%
df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0      1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1      2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2      5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 3      1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 4      3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
#
#    Number of siblings  Gender  Left - right handed                Education  \
# 0                 1.0  female         right handed  college/bachelor degree
# 1                 2.0  female         right handed  college/bachelor degree
# 2                 2.0  female         right handed         secondary school
# 3                 1.0  female         right handed  college/bachelor degree
# 4                 1.0  female         right handed         secondary school
#
#    Only child  Village - town  House - block of flats
# 0          no         village          block of flats
# 1          no            city          block of flats
# 2          no            city          block of flats
# 3         yes            city          house/bungalow
# 4          no         village          house/bungalow
#
# [5 rows x 150 columns]

# %%
agent = Agent(df, config={"llm": llm, "verbose":True})

# %% [markdown]
# # Detekcija autlajera

# %% [markdown]
# #### Prikazujemo sve autlajere po atributu Height

# %%
agent.chat('Find outliers for the Height attribute.')
# Out:
# 2024-10-11 10:11:05 [INFO] Question: Find outliers for the Height attribute.
# 2024-10-11 10:11:05 [INFO] Running PandasAI with langchain_ollama-llm LLM...
# 2024-10-11 10:11:05 [INFO] Prompt ID: fe3fad4c-87a6-4134-beb2-0d813ed9d52d
# 2024-10-11 10:11:05 [INFO] Executing Pipeline: GenerateChatPipeline
# 2024-10-11 10:11:05 [INFO] Executing Step 0: ValidatePipelineInput
# 2024-10-11 10:11:05 [INFO] Executing Step 1: CacheLookup
# 2024-10-11 10:11:05 [INFO] Executing Step 2: PromptGeneration
# 2024-10-11 10:11:06 [INFO] Querying without using training data.
# 2024-10-11 10:11:07 [INFO] Querying without using training docs.
# 2024-10-11 10:11:07 [INFO] Using prompt: <dataframe>
# dfs[0]:1010x150
# Music,Slow songs or fast songs,Dance,Folk,Country,Classical music,Musical,Pop,Rock,Metal or Hardrock,Punk,"Hiphop, Rap","Reggae, Ska","Swing, Jazz",Rock n roll,Alternative,Latino,"Techno, Trance",Opera,Movies,Horror,Thriller,Comedy,Romantic,Sci-fi,War,Fantasy/Fairy tales,Animated,Documentary,Western,Action,History,Psychology,Politics,Mathematics,Physics,Internet,PC,Economy Management,Biology,Chemistry,Reading,Geography,Foreign languages,Medicine,Law,Cars,Art exhibitions,Religion,"Countryside, outdoors",Dancing,Musical instruments,Writing,Passive sport,Active sport,Gardening,Celebrities,Shopping,Science and technology,Theatre,Fun with friends,Adrenaline sports,Pets,Flying,Storm,Darkness,Heights,Spiders,Snakes,Rats,Ageing,Dangerous dogs,Fear of public speaking,Smoking,Alcohol,Healthy eating,Daily events,Prioritising workload,Writing notes,Workaholism,Thinking ahead,Final judgement,Reliability,Keeping promises,Loss of interest,Friends versus money,Funniness,Fake,Criminal damage,Decision making,Elections,Self-criticism,Judgment calls,Hypochondria,Empathy,Eating to survive,Giving,Compassion to animals,Borrowed stuff,Loneliness,Cheating in school,Health,Changing the past,God,Dreams,Charity,Number of friends,Punctuality,Lying,Waiting,New environment,Mood swings,Appearence and gestures,Socializing,Achievements,Responding to a serious letter,Children,Assertiveness,Getting angry,Knowing the right people,Public speaking,Unpopularity,Life struggles,Happiness in life,Energy levels,Small - big dogs,Personality,Finding lost valuables,Getting up,Interests or hobbies,Parents' advice,Questionnaires or polls,Internet usage,Finances,Shopping centres,Branded clothing,Entertainment spending,Spending on looks,Spending on gadgets,Spending on healthy eating,Age,Height,Weight,Number of siblings,Gender,Left - right handed,Education,Only child,Village - town,House - block of flats
# ,2.0,3.0,,,,3.0,4.0,,,,3.0,,,2.0,,5.0,,1.0,,,1.0,2.0,3.0,4.0,,3.0,,5.0,1.0,2.0,,4.0,,1.0,4.0,2.0,1.0,,1.0,,,4.0,,5.0,,1.0,1.0,,5.0,1.0,2.0,,5.0,1.0,3.0,1.0,1.0,5.0,,,4.0,5.0,2.0,4.0,4.0,1.0,,5,,4.0,4.0,,never smoked,never,2.0,5.0,3.0,,,2.0,5.0,3.0,2.0,3.0,,5.0,1.0,4.0,5.0,2.0,1.0,2.0,2.0,,1,,2.0,,3.0,1.0,5.0,,5.0,2,1.0,2,i am always on time,never,5.0,,,2.0,3.0,4.0,2.0,3.0,3.0,,3.0,5.0,3.0,4.0,,,5.0,2.0,2.0,,4.0,3.0,3.0,most of the day,,,,1.0,,2,,,184.0,,3.0,male,right handed,college/bachelor degree,,village,house/bungalow
# 3.0,,4.0,3.0,1.0,3.0,,,3.0,3.0,1.0,4.0,2.0,2.0,1.0,3.0,1.0,1.0,2.0,2.0,1.0,,,1.0,,2.0,2.0,1.0,,,,4.0,,1.0,4.0,5.0,1.0,,4.0,,1.0,3.0,,2.0,,2.0,,,1.0,,,,3.0,1.0,,,5.0,5.0,3.0,1.0,2.0,3.0,1.0,,,5.0,5.0,3.0,3,1.0,,3.0,1.0,,drink a lot,1.0,,2.0,3.0,1.0,4.0,,,,1.0,2.0,1.0,4.0,,,,,,,1.0,3,4.0,3.0,3.0,,,,1.0,,3,,1,i am often early,,3.0,2.0,1.0,,,,,4.0,2.0,1.0,,3.0,5.0,1.0,3.0,5.0,2.0,5.0,,3.0,2.0,1.0,1.0,no time at all,3.0,5.0,5.0,2.0,1.0,3,4.0,25.0,163.0,86.0,,female,,,yes,city,block of flats
# 1.0,4.0,,4.0,4.0,1.0,2.0,5.0,2.0,2.0,5.0,,4.0,5.0,,4.0,,3.0,,5.0,4.0,2.0,1.0,,1.0,5.0,,5.0,2.0,4.0,1.0,5.0,1.0,4.0,,,,4.0,5.0,3.0,3.0,5.0,1.0,5.0,4.0,3.0,5.0,5.0,4.0,4.0,4.0,4.0,4.0,,5.0,1.0,,,,2.0,3.0,,,1.0,1.0,,,2.0,4,5.0,5.0,,4.0,former smoker,,,1.0,,1.0,4.0,,3.0,1.0,3.0,,4.0,,,1.0,3.0,1.0,4.0,3.0,1.0,4.0,2,1.0,,1.0,4.0,3.0,4.0,2.0,4.0,5,5.0,4,,only to avoid hurting someone,,4.0,4.0,1.0,5.0,5.0,1.0,,,3.0,4.0,,,,5.0,1.0,,,3.0,1.0,,,,less than an hour a day,4.0,3.0,4.0,,3.0,4,3.0,28.0,,70.0,1.0,,left handed,currently a primary school pupil,no,,
# </dataframe>
#
#
#
#
# Update this initial code:
# ```python
# # TODO: import the required dependencies
# import pandas as pd
#
# # Write code here
#
# # Declare result var:
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
# ```
#
#
#
#
#
#
#
# ### QUERY
#  Find outliers for the Height attribute.
#
# Variable `dfs: list[pd.DataFrame]` is already declared.
#
# At the end, declare "result" variable as a dictionary of type and value.
#
# If you are asked to plot a chart, use "matplotlib" for charts, save as png.
#
#
# Generate python code and return full updated code:
# 2024-10-11 10:11:07 [INFO] Executing Step 3: CodeGenerator
# 2024-10-11 10:13:32 [INFO] Prompt used:
#
# <dataframe>
# dfs[0]:1010x150
# Music,Slow songs or fast songs,Dance,Folk,Country,Classical music,Musical,Pop,Rock,Metal or Hardrock,Punk,"Hiphop, Rap","Reggae, Ska","Swing, Jazz",Rock n roll,Alternative,Latino,"Techno, Trance",Opera,Movies,Horror,Thriller,Comedy,Romantic,Sci-fi,War,Fantasy/Fairy tales,Animated,Documentary,Western,Action,History,Psychology,Politics,Mathematics,Physics,Internet,PC,Economy Management,Biology,Chemistry,Reading,Geography,Foreign languages,Medicine,Law,Cars,Art exhibitions,Religion,"Countryside, outdoors",Dancing,Musical instruments,Writing,Passive sport,Active sport,Gardening,Celebrities,Shopping,Science and technology,Theatre,Fun with friends,Adrenaline sports,Pets,Flying,Storm,Darkness,Heights,Spiders,Snakes,Rats,Ageing,Dangerous dogs,Fear of public speaking,Smoking,Alcohol,Healthy eating,Daily events,Prioritising workload,Writing notes,Workaholism,Thinking ahead,Final judgement,Reliability,Keeping promises,Loss of interest,Friends versus money,Funniness,Fake,Criminal damage,Decision making,Elections,Self-criticism,Judgment calls,Hypochondria,Empathy,Eating to survive,Giving,Compassion to animals,Borrowed stuff,Loneliness,Cheating in school,Health,Changing the past,God,Dreams,Charity,Number of friends,Punctuality,Lying,Waiting,New environment,Mood swings,Appearence and gestures,Socializing,Achievements,Responding to a serious letter,Children,Assertiveness,Getting angry,Knowing the right people,Public speaking,Unpopularity,Life struggles,Happiness in life,Energy levels,Small - big dogs,Personality,Finding lost valuables,Getting up,Interests or hobbies,Parents' advice,Questionnaires or polls,Internet usage,Finances,Shopping centres,Branded clothing,Entertainment spending,Spending on looks,Spending on gadgets,Spending on healthy eating,Age,Height,Weight,Number of siblings,Gender,Left - right handed,Education,Only child,Village - town,House - block of flats
# ,2.0,3.0,,,,3.0,4.0,,,,3.0,,,2.0,,5.0,,1.0,,,1.0,2.0,3.0,4.0,,3.0,,5.0,1.0,2.0,,4.0,,1.0,4.0,2.0,1.0,,1.0,,,4.0,,5.0,,1.0,1.0,,5.0,1.0,2.0,,5.0,1.0,3.0,1.0,1.0,5.0,,,4.0,5.0,2.0,4.0,4.0,1.0,,5,,4.0,4.0,,never smoked,never,2.0,5.0,3.0,,,2.0,5.0,3.0,2.0,3.0,,5.0,1.0,4.0,5.0,2.0,1.0,2.0,2.0,,1,,2.0,,3.0,1.0,5.0,,5.0,2,1.0,2,i am always on time,never,5.0,,,2.0,3.0,4.0,2.0,3.0,3.0,,3.0,5.0,3.0,4.0,,,5.0,2.0,2.0,,4.0,3.0,3.0,most of the day,,,,1.0,,2,,,184.0,,3.0,male,right handed,college/bachelor degree,,village,house/bungalow
# 3.0,,4.0,3.0,1.0,3.0,,,3.0,3.0,1.0,4.0,2.0,2.0,1.0,3.0,1.0,1.0,2.0,2.0,1.0,,,1.0,,2.0,2.0,1.0,,,,4.0,,1.0,4.0,5.0,1.0,,4.0,,1.0,3.0,,2.0,,2.0,,,1.0,,,,3.0,1.0,,,5.0,5.0,3.0,1.0,2.0,3.0,1.0,,,5.0,5.0,3.0,3,1.0,,3.0,1.0,,drink a lot,1.0,,2.0,3.0,1.0,4.0,,,,1.0,2.0,1.0,4.0,,,,,,,1.0,3,4.0,3.0,3.0,,,,1.0,,3,,1,i am often early,,3.0,2.0,1.0,,,,,4.0,2.0,1.0,,3.0,5.0,1.0,3.0,5.0,2.0,5.0,,3.0,2.0,1.0,1.0,no time at all,3.0,5.0,5.0,2.0,1.0,3,4.0,25.0,163.0,86.0,,female,,,yes,city,block of flats
# 1.0,4.0,,4.0,4.0,1.0,2.0,5.0,2.0,2.0,5.0,,4.0,5.0,,4.0,,3.0,,5.0,4.0,2.0,1.0,,1.0,5.0,,5.0,2.0,4.0,1.0,5.0,1.0,4.0,,,,4.0,5.0,3.0,3.0,5.0,1.0,5.0,4.0,3.0,5.0,5.0,4.0,4.0,4.0,4.0,4.0,,5.0,1.0,,,,2.0,3.0,,,1.0,1.0,,,2.0,4,5.0,5.0,,4.0,former smoker,,,1.0,,1.0,4.0,,3.0,1.0,3.0,,4.0,,,1.0,3.0,1.0,4.0,3.0,1.0,4.0,2,1.0,,1.0,4.0,3.0,4.0,2.0,4.0,5,5.0,4,,only to avoid hurting someone,,4.0,4.0,1.0,5.0,5.0,1.0,,,3.0,4.0,,,,5.0,1.0,,,3.0,1.0,,,,less than an hour a day,4.0,3.0,4.0,,3.0,4,3.0,28.0,,70.0,1.0,,left handed,currently a primary school pupil,no,,
# </dataframe>
#
#
#
#
# Update this initial code:
# ```python
# # TODO: import the required dependencies
# import pandas as pd
#
# # Write code here
#
# # Declare result var:
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
# ```
#
#
#
#
#
#
#
# ### QUERY
#  Find outliers for the Height attribute.
#
# Variable `dfs: list[pd.DataFrame]` is already declared.
#
# At the end, declare "result" variable as a dictionary of type and value.
#
# If you are asked to plot a chart, use "matplotlib" for charts, save as png.
#
#
# Generate python code and return full updated code:
#
# 2024-10-11 10:13:32 [INFO] Code generated:
#             ```
#             # TODO: import the required dependencies
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Write code here
#
# # Declare result var:
# outliers = {}
#
# def find_outliers(df):
#     # Calculate mean and standard deviation for Height attribute
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#
#     # Find outliers using 3-sigma rule
#     outlier_df = df[(df['Height'] < (height_mean - 3 * height_std)) | (df['Height'] > (height_mean + 3 * height_std))]
#
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#
# find_outliers(dfs[0])
# outliers['type'] = 'string'
# outliers['value'] = f"Outlier values for Height attribute: {len(outlier_df)}"
#
# # If you want to plot a chart:
# # height_mean = df['Height'].mean()
# # height_std = df['Height'].std()
# # plt.hist(df['Height'], bins=10)
# # plt.axvline(x=height_mean, color='r', label=f'Mean Height: {height_mean:.2f}')
# # plt.axvline(x=height_mean + 3*height_std, color='g', label=f'3-sigma above mean')
# # plt.axvline(x=height_mean - 3*height_std, color='g', label=f'3-sigma below mean')
# # plt.legend()
# # plt.title('Histogram of Height Attribute with Mean and Outliers')
# # plt.savefig('outlier_chart.png')
#             ```
#
# 2024-10-11 10:13:32 [INFO] Executing Step 4: CachePopulation
# 2024-10-11 10:13:32 [INFO] Executing Step 5: CodeCleaning
# 2024-10-11 10:13:32 [INFO] Saving charts to C:\Users\kocha\Dropbox\nastava\Data_Mining\2020_21\Python_primeri\Data_wrangling\svi_primeri_zajedno\exports\charts\temp_chart.png
# 2024-10-11 10:13:32 [INFO]
# Code running:
# ```
# outliers = {}
#
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#
#
# find_outliers(dfs[0])
# outliers['type'] = 'string'
# outliers['value'] = f'Outlier values for Height attribute: {len(outlier_df)}'
#         ```
# 2024-10-11 10:13:32 [INFO] Executing Step 6: CodeExecution
# 2024-10-11 10:13:32 [ERROR] Unable to extract filters for passed code
# 2024-10-11 10:13:32 [ERROR] Failed with error: Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 171, in execute_code
#     exec(code, environment)
#   File "<string>", line 14, in <module>
# NameError: name 'outlier_df' is not defined
#
# 2024-10-11 10:13:32 [WARNING] Failed to execute code retrying with a correction framework [retry number: 1]
# 2024-10-11 10:13:32 [INFO] Executing Pipeline: ErrorCorrectionPipeline
# 2024-10-11 10:13:33 [INFO] Executing Step 0: ErrorPromptGeneration
# 2024-10-11 10:13:33 [INFO] Using prompt: <dataframe>
# dfs[0]:1010x150
# Music,Slow songs or fast songs,Dance,Folk,Country,Classical music,Musical,Pop,Rock,Metal or Hardrock,Punk,"Hiphop, Rap","Reggae, Ska","Swing, Jazz",Rock n roll,Alternative,Latino,"Techno, Trance",Opera,Movies,Horror,Thriller,Comedy,Romantic,Sci-fi,War,Fantasy/Fairy tales,Animated,Documentary,Western,Action,History,Psychology,Politics,Mathematics,Physics,Internet,PC,Economy Management,Biology,Chemistry,Reading,Geography,Foreign languages,Medicine,Law,Cars,Art exhibitions,Religion,"Countryside, outdoors",Dancing,Musical instruments,Writing,Passive sport,Active sport,Gardening,Celebrities,Shopping,Science and technology,Theatre,Fun with friends,Adrenaline sports,Pets,Flying,Storm,Darkness,Heights,Spiders,Snakes,Rats,Ageing,Dangerous dogs,Fear of public speaking,Smoking,Alcohol,Healthy eating,Daily events,Prioritising workload,Writing notes,Workaholism,Thinking ahead,Final judgement,Reliability,Keeping promises,Loss of interest,Friends versus money,Funniness,Fake,Criminal damage,Decision making,Elections,Self-criticism,Judgment calls,Hypochondria,Empathy,Eating to survive,Giving,Compassion to animals,Borrowed stuff,Loneliness,Cheating in school,Health,Changing the past,God,Dreams,Charity,Number of friends,Punctuality,Lying,Waiting,New environment,Mood swings,Appearence and gestures,Socializing,Achievements,Responding to a serious letter,Children,Assertiveness,Getting angry,Knowing the right people,Public speaking,Unpopularity,Life struggles,Happiness in life,Energy levels,Small - big dogs,Personality,Finding lost valuables,Getting up,Interests or hobbies,Parents' advice,Questionnaires or polls,Internet usage,Finances,Shopping centres,Branded clothing,Entertainment spending,Spending on looks,Spending on gadgets,Spending on healthy eating,Age,Height,Weight,Number of siblings,Gender,Left - right handed,Education,Only child,Village - town,House - block of flats
# ,2.0,3.0,,,,3.0,4.0,,,,3.0,,,2.0,,5.0,,1.0,,,1.0,2.0,3.0,4.0,,3.0,,5.0,1.0,2.0,,4.0,,1.0,4.0,2.0,1.0,,1.0,,,4.0,,5.0,,1.0,1.0,,5.0,1.0,2.0,,5.0,1.0,3.0,1.0,1.0,5.0,,,4.0,5.0,2.0,4.0,4.0,1.0,,5,,4.0,4.0,,never smoked,never,2.0,5.0,3.0,,,2.0,5.0,3.0,2.0,3.0,,5.0,1.0,4.0,5.0,2.0,1.0,2.0,2.0,,1,,2.0,,3.0,1.0,5.0,,5.0,2,1.0,2,i am always on time,never,5.0,,,2.0,3.0,4.0,2.0,3.0,3.0,,3.0,5.0,3.0,4.0,,,5.0,2.0,2.0,,4.0,3.0,3.0,most of the day,,,,1.0,,2,,,184.0,,3.0,male,right handed,college/bachelor degree,,village,house/bungalow
# 3.0,,4.0,3.0,1.0,3.0,,,3.0,3.0,1.0,4.0,2.0,2.0,1.0,3.0,1.0,1.0,2.0,2.0,1.0,,,1.0,,2.0,2.0,1.0,,,,4.0,,1.0,4.0,5.0,1.0,,4.0,,1.0,3.0,,2.0,,2.0,,,1.0,,,,3.0,1.0,,,5.0,5.0,3.0,1.0,2.0,3.0,1.0,,,5.0,5.0,3.0,3,1.0,,3.0,1.0,,drink a lot,1.0,,2.0,3.0,1.0,4.0,,,,1.0,2.0,1.0,4.0,,,,,,,1.0,3,4.0,3.0,3.0,,,,1.0,,3,,1,i am often early,,3.0,2.0,1.0,,,,,4.0,2.0,1.0,,3.0,5.0,1.0,3.0,5.0,2.0,5.0,,3.0,2.0,1.0,1.0,no time at all,3.0,5.0,5.0,2.0,1.0,3,4.0,25.0,163.0,86.0,,female,,,yes,city,block of flats
# 1.0,4.0,,4.0,4.0,1.0,2.0,5.0,2.0,2.0,5.0,,4.0,5.0,,4.0,,3.0,,5.0,4.0,2.0,1.0,,1.0,5.0,,5.0,2.0,4.0,1.0,5.0,1.0,4.0,,,,4.0,5.0,3.0,3.0,5.0,1.0,5.0,4.0,3.0,5.0,5.0,4.0,4.0,4.0,4.0,4.0,,5.0,1.0,,,,2.0,3.0,,,1.0,1.0,,,2.0,4,5.0,5.0,,4.0,former smoker,,,1.0,,1.0,4.0,,3.0,1.0,3.0,,4.0,,,1.0,3.0,1.0,4.0,3.0,1.0,4.0,2,1.0,,1.0,4.0,3.0,4.0,2.0,4.0,5,5.0,4,,only to avoid hurting someone,,4.0,4.0,1.0,5.0,5.0,1.0,,,3.0,4.0,,,,5.0,1.0,,,3.0,1.0,,,,less than an hour a day,4.0,3.0,4.0,,3.0,4,3.0,28.0,,70.0,1.0,,left handed,currently a primary school pupil,no,,
# </dataframe>
#
#
# The user asked the following question:
# ### QUERY
#  Find outliers for the Height attribute.
#
# You generated this python code:
# outliers = {}
#
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#
#
# find_outliers(dfs[0])
# outliers['type'] = 'string'
# outliers['value'] = f'Outlier values for Height attribute: {len(outlier_df)}'
#
# It fails with the following error:
# Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 171, in execute_code
#     exec(code, environment)
#   File "<string>", line 14, in <module>
# NameError: name 'outlier_df' is not defined
#
#
# Fix the python code above and return the new python code:
# 2024-10-11 10:13:33 [INFO] Executing Step 1: CodeGenerator
# 2024-10-11 10:15:57 [INFO] Prompt used:
#
# <dataframe>
# dfs[0]:1010x150
# Music,Slow songs or fast songs,Dance,Folk,Country,Classical music,Musical,Pop,Rock,Metal or Hardrock,Punk,"Hiphop, Rap","Reggae, Ska","Swing, Jazz",Rock n roll,Alternative,Latino,"Techno, Trance",Opera,Movies,Horror,Thriller,Comedy,Romantic,Sci-fi,War,Fantasy/Fairy tales,Animated,Documentary,Western,Action,History,Psychology,Politics,Mathematics,Physics,Internet,PC,Economy Management,Biology,Chemistry,Reading,Geography,Foreign languages,Medicine,Law,Cars,Art exhibitions,Religion,"Countryside, outdoors",Dancing,Musical instruments,Writing,Passive sport,Active sport,Gardening,Celebrities,Shopping,Science and technology,Theatre,Fun with friends,Adrenaline sports,Pets,Flying,Storm,Darkness,Heights,Spiders,Snakes,Rats,Ageing,Dangerous dogs,Fear of public speaking,Smoking,Alcohol,Healthy eating,Daily events,Prioritising workload,Writing notes,Workaholism,Thinking ahead,Final judgement,Reliability,Keeping promises,Loss of interest,Friends versus money,Funniness,Fake,Criminal damage,Decision making,Elections,Self-criticism,Judgment calls,Hypochondria,Empathy,Eating to survive,Giving,Compassion to animals,Borrowed stuff,Loneliness,Cheating in school,Health,Changing the past,God,Dreams,Charity,Number of friends,Punctuality,Lying,Waiting,New environment,Mood swings,Appearence and gestures,Socializing,Achievements,Responding to a serious letter,Children,Assertiveness,Getting angry,Knowing the right people,Public speaking,Unpopularity,Life struggles,Happiness in life,Energy levels,Small - big dogs,Personality,Finding lost valuables,Getting up,Interests or hobbies,Parents' advice,Questionnaires or polls,Internet usage,Finances,Shopping centres,Branded clothing,Entertainment spending,Spending on looks,Spending on gadgets,Spending on healthy eating,Age,Height,Weight,Number of siblings,Gender,Left - right handed,Education,Only child,Village - town,House - block of flats
# ,2.0,3.0,,,,3.0,4.0,,,,3.0,,,2.0,,5.0,,1.0,,,1.0,2.0,3.0,4.0,,3.0,,5.0,1.0,2.0,,4.0,,1.0,4.0,2.0,1.0,,1.0,,,4.0,,5.0,,1.0,1.0,,5.0,1.0,2.0,,5.0,1.0,3.0,1.0,1.0,5.0,,,4.0,5.0,2.0,4.0,4.0,1.0,,5,,4.0,4.0,,never smoked,never,2.0,5.0,3.0,,,2.0,5.0,3.0,2.0,3.0,,5.0,1.0,4.0,5.0,2.0,1.0,2.0,2.0,,1,,2.0,,3.0,1.0,5.0,,5.0,2,1.0,2,i am always on time,never,5.0,,,2.0,3.0,4.0,2.0,3.0,3.0,,3.0,5.0,3.0,4.0,,,5.0,2.0,2.0,,4.0,3.0,3.0,most of the day,,,,1.0,,2,,,184.0,,3.0,male,right handed,college/bachelor degree,,village,house/bungalow
# 3.0,,4.0,3.0,1.0,3.0,,,3.0,3.0,1.0,4.0,2.0,2.0,1.0,3.0,1.0,1.0,2.0,2.0,1.0,,,1.0,,2.0,2.0,1.0,,,,4.0,,1.0,4.0,5.0,1.0,,4.0,,1.0,3.0,,2.0,,2.0,,,1.0,,,,3.0,1.0,,,5.0,5.0,3.0,1.0,2.0,3.0,1.0,,,5.0,5.0,3.0,3,1.0,,3.0,1.0,,drink a lot,1.0,,2.0,3.0,1.0,4.0,,,,1.0,2.0,1.0,4.0,,,,,,,1.0,3,4.0,3.0,3.0,,,,1.0,,3,,1,i am often early,,3.0,2.0,1.0,,,,,4.0,2.0,1.0,,3.0,5.0,1.0,3.0,5.0,2.0,5.0,,3.0,2.0,1.0,1.0,no time at all,3.0,5.0,5.0,2.0,1.0,3,4.0,25.0,163.0,86.0,,female,,,yes,city,block of flats
# 1.0,4.0,,4.0,4.0,1.0,2.0,5.0,2.0,2.0,5.0,,4.0,5.0,,4.0,,3.0,,5.0,4.0,2.0,1.0,,1.0,5.0,,5.0,2.0,4.0,1.0,5.0,1.0,4.0,,,,4.0,5.0,3.0,3.0,5.0,1.0,5.0,4.0,3.0,5.0,5.0,4.0,4.0,4.0,4.0,4.0,,5.0,1.0,,,,2.0,3.0,,,1.0,1.0,,,2.0,4,5.0,5.0,,4.0,former smoker,,,1.0,,1.0,4.0,,3.0,1.0,3.0,,4.0,,,1.0,3.0,1.0,4.0,3.0,1.0,4.0,2,1.0,,1.0,4.0,3.0,4.0,2.0,4.0,5,5.0,4,,only to avoid hurting someone,,4.0,4.0,1.0,5.0,5.0,1.0,,,3.0,4.0,,,,5.0,1.0,,,3.0,1.0,,,,less than an hour a day,4.0,3.0,4.0,,3.0,4,3.0,28.0,,70.0,1.0,,left handed,currently a primary school pupil,no,,
# </dataframe>
#
#
# The user asked the following question:
# ### QUERY
#  Find outliers for the Height attribute.
#
# You generated this python code:
# outliers = {}
#
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#
#
# find_outliers(dfs[0])
# outliers['type'] = 'string'
# outliers['value'] = f'Outlier values for Height attribute: {len(outlier_df)}'
#
# It fails with the following error:
# Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 171, in execute_code
#     exec(code, environment)
#   File "<string>", line 14, in <module>
# NameError: name 'outlier_df' is not defined
#
#
# Fix the python code above and return the new python code:
#
# 2024-10-11 10:15:57 [INFO] Code generated:
#             ```
#             outliers = {}
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < (height_mean - 3 * height_std)) | (df['Height'] > (height_mean + 3 * height_std))]
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#
# find_outliers(dfs[0])
# outliers['type'] = 'string'
# outliers['value'] = f'Outlier values for Height attribute: {len(outliers["value"])}'
#
# print(outliers)
#             ```
#
# 2024-10-11 10:15:57 [INFO] Executing Step 2: CodeCleaning
# 2024-10-11 10:15:57 [INFO]
# Code running:
# ```
# outliers = {}
#
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#
#
# find_outliers(dfs[0])
# outliers['type'] = 'string'
# outliers['value'] = f"Outlier values for Height attribute: {len(outliers['value'])}"
# print(outliers)
#         ```
# 2024-10-11 10:15:57 [ERROR] Unable to extract filters for passed code
# {'type': 'string', 'value': 'Outlier values for Height attribute: 1'}
# 2024-10-11 10:15:57 [ERROR] Failed with error: Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# 2024-10-11 10:15:57 [WARNING] Failed to execute code retrying with a correction framework [retry number: 2]
# 2024-10-11 10:15:57 [INFO] Executing Pipeline: ErrorCorrectionPipeline
# 2024-10-11 10:15:58 [INFO] Executing Step 0: ErrorPromptGeneration
# 2024-10-11 10:15:58 [INFO] Using prompt: <dataframe>
# dfs[0]:1010x150
# Music,Slow songs or fast songs,Dance,Folk,Country,Classical music,Musical,Pop,Rock,Metal or Hardrock,Punk,"Hiphop, Rap","Reggae, Ska","Swing, Jazz",Rock n roll,Alternative,Latino,"Techno, Trance",Opera,Movies,Horror,Thriller,Comedy,Romantic,Sci-fi,War,Fantasy/Fairy tales,Animated,Documentary,Western,Action,History,Psychology,Politics,Mathematics,Physics,Internet,PC,Economy Management,Biology,Chemistry,Reading,Geography,Foreign languages,Medicine,Law,Cars,Art exhibitions,Religion,"Countryside, outdoors",Dancing,Musical instruments,Writing,Passive sport,Active sport,Gardening,Celebrities,Shopping,Science and technology,Theatre,Fun with friends,Adrenaline sports,Pets,Flying,Storm,Darkness,Heights,Spiders,Snakes,Rats,Ageing,Dangerous dogs,Fear of public speaking,Smoking,Alcohol,Healthy eating,Daily events,Prioritising workload,Writing notes,Workaholism,Thinking ahead,Final judgement,Reliability,Keeping promises,Loss of interest,Friends versus money,Funniness,Fake,Criminal damage,Decision making,Elections,Self-criticism,Judgment calls,Hypochondria,Empathy,Eating to survive,Giving,Compassion to animals,Borrowed stuff,Loneliness,Cheating in school,Health,Changing the past,God,Dreams,Charity,Number of friends,Punctuality,Lying,Waiting,New environment,Mood swings,Appearence and gestures,Socializing,Achievements,Responding to a serious letter,Children,Assertiveness,Getting angry,Knowing the right people,Public speaking,Unpopularity,Life struggles,Happiness in life,Energy levels,Small - big dogs,Personality,Finding lost valuables,Getting up,Interests or hobbies,Parents' advice,Questionnaires or polls,Internet usage,Finances,Shopping centres,Branded clothing,Entertainment spending,Spending on looks,Spending on gadgets,Spending on healthy eating,Age,Height,Weight,Number of siblings,Gender,Left - right handed,Education,Only child,Village - town,House - block of flats
# ,2.0,3.0,,,,3.0,4.0,,,,3.0,,,2.0,,5.0,,1.0,,,1.0,2.0,3.0,4.0,,3.0,,5.0,1.0,2.0,,4.0,,1.0,4.0,2.0,1.0,,1.0,,,4.0,,5.0,,1.0,1.0,,5.0,1.0,2.0,,5.0,1.0,3.0,1.0,1.0,5.0,,,4.0,5.0,2.0,4.0,4.0,1.0,,5,,4.0,4.0,,never smoked,never,2.0,5.0,3.0,,,2.0,5.0,3.0,2.0,3.0,,5.0,1.0,4.0,5.0,2.0,1.0,2.0,2.0,,1,,2.0,,3.0,1.0,5.0,,5.0,2,1.0,2,i am always on time,never,5.0,,,2.0,3.0,4.0,2.0,3.0,3.0,,3.0,5.0,3.0,4.0,,,5.0,2.0,2.0,,4.0,3.0,3.0,most of the day,,,,1.0,,2,,,184.0,,3.0,male,right handed,college/bachelor degree,,village,house/bungalow
# 3.0,,4.0,3.0,1.0,3.0,,,3.0,3.0,1.0,4.0,2.0,2.0,1.0,3.0,1.0,1.0,2.0,2.0,1.0,,,1.0,,2.0,2.0,1.0,,,,4.0,,1.0,4.0,5.0,1.0,,4.0,,1.0,3.0,,2.0,,2.0,,,1.0,,,,3.0,1.0,,,5.0,5.0,3.0,1.0,2.0,3.0,1.0,,,5.0,5.0,3.0,3,1.0,,3.0,1.0,,drink a lot,1.0,,2.0,3.0,1.0,4.0,,,,1.0,2.0,1.0,4.0,,,,,,,1.0,3,4.0,3.0,3.0,,,,1.0,,3,,1,i am often early,,3.0,2.0,1.0,,,,,4.0,2.0,1.0,,3.0,5.0,1.0,3.0,5.0,2.0,5.0,,3.0,2.0,1.0,1.0,no time at all,3.0,5.0,5.0,2.0,1.0,3,4.0,25.0,163.0,86.0,,female,,,yes,city,block of flats
# 1.0,4.0,,4.0,4.0,1.0,2.0,5.0,2.0,2.0,5.0,,4.0,5.0,,4.0,,3.0,,5.0,4.0,2.0,1.0,,1.0,5.0,,5.0,2.0,4.0,1.0,5.0,1.0,4.0,,,,4.0,5.0,3.0,3.0,5.0,1.0,5.0,4.0,3.0,5.0,5.0,4.0,4.0,4.0,4.0,4.0,,5.0,1.0,,,,2.0,3.0,,,1.0,1.0,,,2.0,4,5.0,5.0,,4.0,former smoker,,,1.0,,1.0,4.0,,3.0,1.0,3.0,,4.0,,,1.0,3.0,1.0,4.0,3.0,1.0,4.0,2,1.0,,1.0,4.0,3.0,4.0,2.0,4.0,5,5.0,4,,only to avoid hurting someone,,4.0,4.0,1.0,5.0,5.0,1.0,,,3.0,4.0,,,,5.0,1.0,,,3.0,1.0,,,,less than an hour a day,4.0,3.0,4.0,,3.0,4,3.0,28.0,,70.0,1.0,,left handed,currently a primary school pupil,no,,
# </dataframe>
#
#
# The user asked the following question:
# ### QUERY
#  Find outliers for the Height attribute.
#
# You generated this python code:
# outliers = {}
#
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#
#
# find_outliers(dfs[0])
# outliers['type'] = 'string'
# outliers['value'] = f"Outlier values for Height attribute: {len(outliers['value'])}"
# print(outliers)
#
# It fails with the following error:
# Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
#
# Fix the python code above and return the new python code:
# 2024-10-11 10:15:58 [INFO] Executing Step 1: CodeGenerator
# 2024-10-11 10:18:07 [INFO] Prompt used:
#
# <dataframe>
# dfs[0]:1010x150
# Music,Slow songs or fast songs,Dance,Folk,Country,Classical music,Musical,Pop,Rock,Metal or Hardrock,Punk,"Hiphop, Rap","Reggae, Ska","Swing, Jazz",Rock n roll,Alternative,Latino,"Techno, Trance",Opera,Movies,Horror,Thriller,Comedy,Romantic,Sci-fi,War,Fantasy/Fairy tales,Animated,Documentary,Western,Action,History,Psychology,Politics,Mathematics,Physics,Internet,PC,Economy Management,Biology,Chemistry,Reading,Geography,Foreign languages,Medicine,Law,Cars,Art exhibitions,Religion,"Countryside, outdoors",Dancing,Musical instruments,Writing,Passive sport,Active sport,Gardening,Celebrities,Shopping,Science and technology,Theatre,Fun with friends,Adrenaline sports,Pets,Flying,Storm,Darkness,Heights,Spiders,Snakes,Rats,Ageing,Dangerous dogs,Fear of public speaking,Smoking,Alcohol,Healthy eating,Daily events,Prioritising workload,Writing notes,Workaholism,Thinking ahead,Final judgement,Reliability,Keeping promises,Loss of interest,Friends versus money,Funniness,Fake,Criminal damage,Decision making,Elections,Self-criticism,Judgment calls,Hypochondria,Empathy,Eating to survive,Giving,Compassion to animals,Borrowed stuff,Loneliness,Cheating in school,Health,Changing the past,God,Dreams,Charity,Number of friends,Punctuality,Lying,Waiting,New environment,Mood swings,Appearence and gestures,Socializing,Achievements,Responding to a serious letter,Children,Assertiveness,Getting angry,Knowing the right people,Public speaking,Unpopularity,Life struggles,Happiness in life,Energy levels,Small - big dogs,Personality,Finding lost valuables,Getting up,Interests or hobbies,Parents' advice,Questionnaires or polls,Internet usage,Finances,Shopping centres,Branded clothing,Entertainment spending,Spending on looks,Spending on gadgets,Spending on healthy eating,Age,Height,Weight,Number of siblings,Gender,Left - right handed,Education,Only child,Village - town,House - block of flats
# ,2.0,3.0,,,,3.0,4.0,,,,3.0,,,2.0,,5.0,,1.0,,,1.0,2.0,3.0,4.0,,3.0,,5.0,1.0,2.0,,4.0,,1.0,4.0,2.0,1.0,,1.0,,,4.0,,5.0,,1.0,1.0,,5.0,1.0,2.0,,5.0,1.0,3.0,1.0,1.0,5.0,,,4.0,5.0,2.0,4.0,4.0,1.0,,5,,4.0,4.0,,never smoked,never,2.0,5.0,3.0,,,2.0,5.0,3.0,2.0,3.0,,5.0,1.0,4.0,5.0,2.0,1.0,2.0,2.0,,1,,2.0,,3.0,1.0,5.0,,5.0,2,1.0,2,i am always on time,never,5.0,,,2.0,3.0,4.0,2.0,3.0,3.0,,3.0,5.0,3.0,4.0,,,5.0,2.0,2.0,,4.0,3.0,3.0,most of the day,,,,1.0,,2,,,184.0,,3.0,male,right handed,college/bachelor degree,,village,house/bungalow
# 3.0,,4.0,3.0,1.0,3.0,,,3.0,3.0,1.0,4.0,2.0,2.0,1.0,3.0,1.0,1.0,2.0,2.0,1.0,,,1.0,,2.0,2.0,1.0,,,,4.0,,1.0,4.0,5.0,1.0,,4.0,,1.0,3.0,,2.0,,2.0,,,1.0,,,,3.0,1.0,,,5.0,5.0,3.0,1.0,2.0,3.0,1.0,,,5.0,5.0,3.0,3,1.0,,3.0,1.0,,drink a lot,1.0,,2.0,3.0,1.0,4.0,,,,1.0,2.0,1.0,4.0,,,,,,,1.0,3,4.0,3.0,3.0,,,,1.0,,3,,1,i am often early,,3.0,2.0,1.0,,,,,4.0,2.0,1.0,,3.0,5.0,1.0,3.0,5.0,2.0,5.0,,3.0,2.0,1.0,1.0,no time at all,3.0,5.0,5.0,2.0,1.0,3,4.0,25.0,163.0,86.0,,female,,,yes,city,block of flats
# 1.0,4.0,,4.0,4.0,1.0,2.0,5.0,2.0,2.0,5.0,,4.0,5.0,,4.0,,3.0,,5.0,4.0,2.0,1.0,,1.0,5.0,,5.0,2.0,4.0,1.0,5.0,1.0,4.0,,,,4.0,5.0,3.0,3.0,5.0,1.0,5.0,4.0,3.0,5.0,5.0,4.0,4.0,4.0,4.0,4.0,,5.0,1.0,,,,2.0,3.0,,,1.0,1.0,,,2.0,4,5.0,5.0,,4.0,former smoker,,,1.0,,1.0,4.0,,3.0,1.0,3.0,,4.0,,,1.0,3.0,1.0,4.0,3.0,1.0,4.0,2,1.0,,1.0,4.0,3.0,4.0,2.0,4.0,5,5.0,4,,only to avoid hurting someone,,4.0,4.0,1.0,5.0,5.0,1.0,,,3.0,4.0,,,,5.0,1.0,,,3.0,1.0,,,,less than an hour a day,4.0,3.0,4.0,,3.0,4,3.0,28.0,,70.0,1.0,,left handed,currently a primary school pupil,no,,
# </dataframe>
#
#
# The user asked the following question:
# ### QUERY
#  Find outliers for the Height attribute.
#
# You generated this python code:
# outliers = {}
#
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#
#
# find_outliers(dfs[0])
# outliers['type'] = 'string'
# outliers['value'] = f"Outlier values for Height attribute: {len(outliers['value'])}"
# print(outliers)
#
# It fails with the following error:
# Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
#
# Fix the python code above and return the new python code:
#
# 2024-10-11 10:18:07 [INFO] Code generated:
#             ```
#             outliers = {}
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#
#     # Find values outside of 3 standard deviations from the mean
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#
#     return outliers
#
# outliers = find_outliers(dfs[0])
# print(outliers)
#             ```
#
# 2024-10-11 10:18:07 [INFO] Executing Step 2: CodeCleaning
# 2024-10-11 10:18:08 [INFO]
# Code running:
# ```
# outliers = {}
#
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#     return outliers
#
#
# outliers = find_outliers(dfs[0])
# print(outliers)
#         ```
# 2024-10-11 10:18:08 [ERROR] Unable to extract filters for passed code
# {'type': 'dataframe', 'value':      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 676    5.0                       4.0    2.0   2.0      1.0              2.0
#
#      Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 676      2.0  1.0   2.0                2.0  ...  20.0    62.0    55.0
#
#      Number of siblings  Gender  Left - right handed                Education  \
# 676                 2.0  female         right handed  college/bachelor degree
#
#      Only child  Village - town  House - block of flats
# 676          no            city          house/bungalow
#
# [1 rows x 150 columns]}
# 2024-10-11 10:18:08 [ERROR] Failed with error: Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# 2024-10-11 10:18:08 [WARNING] Failed to execute code retrying with a correction framework [retry number: 3]
# 2024-10-11 10:18:08 [INFO] Executing Pipeline: ErrorCorrectionPipeline
# 2024-10-11 10:18:08 [INFO] Executing Step 0: ErrorPromptGeneration
# 2024-10-11 10:18:08 [INFO] Using prompt: <dataframe>
# dfs[0]:1010x150
# Music,Slow songs or fast songs,Dance,Folk,Country,Classical music,Musical,Pop,Rock,Metal or Hardrock,Punk,"Hiphop, Rap","Reggae, Ska","Swing, Jazz",Rock n roll,Alternative,Latino,"Techno, Trance",Opera,Movies,Horror,Thriller,Comedy,Romantic,Sci-fi,War,Fantasy/Fairy tales,Animated,Documentary,Western,Action,History,Psychology,Politics,Mathematics,Physics,Internet,PC,Economy Management,Biology,Chemistry,Reading,Geography,Foreign languages,Medicine,Law,Cars,Art exhibitions,Religion,"Countryside, outdoors",Dancing,Musical instruments,Writing,Passive sport,Active sport,Gardening,Celebrities,Shopping,Science and technology,Theatre,Fun with friends,Adrenaline sports,Pets,Flying,Storm,Darkness,Heights,Spiders,Snakes,Rats,Ageing,Dangerous dogs,Fear of public speaking,Smoking,Alcohol,Healthy eating,Daily events,Prioritising workload,Writing notes,Workaholism,Thinking ahead,Final judgement,Reliability,Keeping promises,Loss of interest,Friends versus money,Funniness,Fake,Criminal damage,Decision making,Elections,Self-criticism,Judgment calls,Hypochondria,Empathy,Eating to survive,Giving,Compassion to animals,Borrowed stuff,Loneliness,Cheating in school,Health,Changing the past,God,Dreams,Charity,Number of friends,Punctuality,Lying,Waiting,New environment,Mood swings,Appearence and gestures,Socializing,Achievements,Responding to a serious letter,Children,Assertiveness,Getting angry,Knowing the right people,Public speaking,Unpopularity,Life struggles,Happiness in life,Energy levels,Small - big dogs,Personality,Finding lost valuables,Getting up,Interests or hobbies,Parents' advice,Questionnaires or polls,Internet usage,Finances,Shopping centres,Branded clothing,Entertainment spending,Spending on looks,Spending on gadgets,Spending on healthy eating,Age,Height,Weight,Number of siblings,Gender,Left - right handed,Education,Only child,Village - town,House - block of flats
# ,2.0,3.0,,,,3.0,4.0,,,,3.0,,,2.0,,5.0,,1.0,,,1.0,2.0,3.0,4.0,,3.0,,5.0,1.0,2.0,,4.0,,1.0,4.0,2.0,1.0,,1.0,,,4.0,,5.0,,1.0,1.0,,5.0,1.0,2.0,,5.0,1.0,3.0,1.0,1.0,5.0,,,4.0,5.0,2.0,4.0,4.0,1.0,,5,,4.0,4.0,,never smoked,never,2.0,5.0,3.0,,,2.0,5.0,3.0,2.0,3.0,,5.0,1.0,4.0,5.0,2.0,1.0,2.0,2.0,,1,,2.0,,3.0,1.0,5.0,,5.0,2,1.0,2,i am always on time,never,5.0,,,2.0,3.0,4.0,2.0,3.0,3.0,,3.0,5.0,3.0,4.0,,,5.0,2.0,2.0,,4.0,3.0,3.0,most of the day,,,,1.0,,2,,,184.0,,3.0,male,right handed,college/bachelor degree,,village,house/bungalow
# 3.0,,4.0,3.0,1.0,3.0,,,3.0,3.0,1.0,4.0,2.0,2.0,1.0,3.0,1.0,1.0,2.0,2.0,1.0,,,1.0,,2.0,2.0,1.0,,,,4.0,,1.0,4.0,5.0,1.0,,4.0,,1.0,3.0,,2.0,,2.0,,,1.0,,,,3.0,1.0,,,5.0,5.0,3.0,1.0,2.0,3.0,1.0,,,5.0,5.0,3.0,3,1.0,,3.0,1.0,,drink a lot,1.0,,2.0,3.0,1.0,4.0,,,,1.0,2.0,1.0,4.0,,,,,,,1.0,3,4.0,3.0,3.0,,,,1.0,,3,,1,i am often early,,3.0,2.0,1.0,,,,,4.0,2.0,1.0,,3.0,5.0,1.0,3.0,5.0,2.0,5.0,,3.0,2.0,1.0,1.0,no time at all,3.0,5.0,5.0,2.0,1.0,3,4.0,25.0,163.0,86.0,,female,,,yes,city,block of flats
# 1.0,4.0,,4.0,4.0,1.0,2.0,5.0,2.0,2.0,5.0,,4.0,5.0,,4.0,,3.0,,5.0,4.0,2.0,1.0,,1.0,5.0,,5.0,2.0,4.0,1.0,5.0,1.0,4.0,,,,4.0,5.0,3.0,3.0,5.0,1.0,5.0,4.0,3.0,5.0,5.0,4.0,4.0,4.0,4.0,4.0,,5.0,1.0,,,,2.0,3.0,,,1.0,1.0,,,2.0,4,5.0,5.0,,4.0,former smoker,,,1.0,,1.0,4.0,,3.0,1.0,3.0,,4.0,,,1.0,3.0,1.0,4.0,3.0,1.0,4.0,2,1.0,,1.0,4.0,3.0,4.0,2.0,4.0,5,5.0,4,,only to avoid hurting someone,,4.0,4.0,1.0,5.0,5.0,1.0,,,3.0,4.0,,,,5.0,1.0,,,3.0,1.0,,,,less than an hour a day,4.0,3.0,4.0,,3.0,4,3.0,28.0,,70.0,1.0,,left handed,currently a primary school pupil,no,,
# </dataframe>
#
#
# The user asked the following question:
# ### QUERY
#  Find outliers for the Height attribute.
#
# You generated this python code:
# outliers = {}
#
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#     return outliers
#
#
# outliers = find_outliers(dfs[0])
# print(outliers)
#
# It fails with the following error:
# Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
#
# Fix the python code above and return the new python code:
# 2024-10-11 10:18:08 [INFO] Executing Step 1: CodeGenerator
# 2024-10-11 10:20:19 [INFO] Prompt used:
#
# <dataframe>
# dfs[0]:1010x150
# Music,Slow songs or fast songs,Dance,Folk,Country,Classical music,Musical,Pop,Rock,Metal or Hardrock,Punk,"Hiphop, Rap","Reggae, Ska","Swing, Jazz",Rock n roll,Alternative,Latino,"Techno, Trance",Opera,Movies,Horror,Thriller,Comedy,Romantic,Sci-fi,War,Fantasy/Fairy tales,Animated,Documentary,Western,Action,History,Psychology,Politics,Mathematics,Physics,Internet,PC,Economy Management,Biology,Chemistry,Reading,Geography,Foreign languages,Medicine,Law,Cars,Art exhibitions,Religion,"Countryside, outdoors",Dancing,Musical instruments,Writing,Passive sport,Active sport,Gardening,Celebrities,Shopping,Science and technology,Theatre,Fun with friends,Adrenaline sports,Pets,Flying,Storm,Darkness,Heights,Spiders,Snakes,Rats,Ageing,Dangerous dogs,Fear of public speaking,Smoking,Alcohol,Healthy eating,Daily events,Prioritising workload,Writing notes,Workaholism,Thinking ahead,Final judgement,Reliability,Keeping promises,Loss of interest,Friends versus money,Funniness,Fake,Criminal damage,Decision making,Elections,Self-criticism,Judgment calls,Hypochondria,Empathy,Eating to survive,Giving,Compassion to animals,Borrowed stuff,Loneliness,Cheating in school,Health,Changing the past,God,Dreams,Charity,Number of friends,Punctuality,Lying,Waiting,New environment,Mood swings,Appearence and gestures,Socializing,Achievements,Responding to a serious letter,Children,Assertiveness,Getting angry,Knowing the right people,Public speaking,Unpopularity,Life struggles,Happiness in life,Energy levels,Small - big dogs,Personality,Finding lost valuables,Getting up,Interests or hobbies,Parents' advice,Questionnaires or polls,Internet usage,Finances,Shopping centres,Branded clothing,Entertainment spending,Spending on looks,Spending on gadgets,Spending on healthy eating,Age,Height,Weight,Number of siblings,Gender,Left - right handed,Education,Only child,Village - town,House - block of flats
# ,2.0,3.0,,,,3.0,4.0,,,,3.0,,,2.0,,5.0,,1.0,,,1.0,2.0,3.0,4.0,,3.0,,5.0,1.0,2.0,,4.0,,1.0,4.0,2.0,1.0,,1.0,,,4.0,,5.0,,1.0,1.0,,5.0,1.0,2.0,,5.0,1.0,3.0,1.0,1.0,5.0,,,4.0,5.0,2.0,4.0,4.0,1.0,,5,,4.0,4.0,,never smoked,never,2.0,5.0,3.0,,,2.0,5.0,3.0,2.0,3.0,,5.0,1.0,4.0,5.0,2.0,1.0,2.0,2.0,,1,,2.0,,3.0,1.0,5.0,,5.0,2,1.0,2,i am always on time,never,5.0,,,2.0,3.0,4.0,2.0,3.0,3.0,,3.0,5.0,3.0,4.0,,,5.0,2.0,2.0,,4.0,3.0,3.0,most of the day,,,,1.0,,2,,,184.0,,3.0,male,right handed,college/bachelor degree,,village,house/bungalow
# 3.0,,4.0,3.0,1.0,3.0,,,3.0,3.0,1.0,4.0,2.0,2.0,1.0,3.0,1.0,1.0,2.0,2.0,1.0,,,1.0,,2.0,2.0,1.0,,,,4.0,,1.0,4.0,5.0,1.0,,4.0,,1.0,3.0,,2.0,,2.0,,,1.0,,,,3.0,1.0,,,5.0,5.0,3.0,1.0,2.0,3.0,1.0,,,5.0,5.0,3.0,3,1.0,,3.0,1.0,,drink a lot,1.0,,2.0,3.0,1.0,4.0,,,,1.0,2.0,1.0,4.0,,,,,,,1.0,3,4.0,3.0,3.0,,,,1.0,,3,,1,i am often early,,3.0,2.0,1.0,,,,,4.0,2.0,1.0,,3.0,5.0,1.0,3.0,5.0,2.0,5.0,,3.0,2.0,1.0,1.0,no time at all,3.0,5.0,5.0,2.0,1.0,3,4.0,25.0,163.0,86.0,,female,,,yes,city,block of flats
# 1.0,4.0,,4.0,4.0,1.0,2.0,5.0,2.0,2.0,5.0,,4.0,5.0,,4.0,,3.0,,5.0,4.0,2.0,1.0,,1.0,5.0,,5.0,2.0,4.0,1.0,5.0,1.0,4.0,,,,4.0,5.0,3.0,3.0,5.0,1.0,5.0,4.0,3.0,5.0,5.0,4.0,4.0,4.0,4.0,4.0,,5.0,1.0,,,,2.0,3.0,,,1.0,1.0,,,2.0,4,5.0,5.0,,4.0,former smoker,,,1.0,,1.0,4.0,,3.0,1.0,3.0,,4.0,,,1.0,3.0,1.0,4.0,3.0,1.0,4.0,2,1.0,,1.0,4.0,3.0,4.0,2.0,4.0,5,5.0,4,,only to avoid hurting someone,,4.0,4.0,1.0,5.0,5.0,1.0,,,3.0,4.0,,,,5.0,1.0,,,3.0,1.0,,,,less than an hour a day,4.0,3.0,4.0,,3.0,4,3.0,28.0,,70.0,1.0,,left handed,currently a primary school pupil,no,,
# </dataframe>
#
#
# The user asked the following question:
# ### QUERY
#  Find outliers for the Height attribute.
#
# You generated this python code:
# outliers = {}
#
#
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     outliers['type'] = 'dataframe'
#     outliers['value'] = outlier_df
#     return outliers
#
#
# outliers = find_outliers(dfs[0])
# print(outliers)
#
# It fails with the following error:
# Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
#
# Fix the python code above and return the new python code:
#
# 2024-10-11 10:20:19 [INFO] Code generated:
#             ```
#             def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     return {'type': 'dataframe', 'value': outlier_df}
#
# outliers = find_outliers(dfs[0])
# print(outliers)
#             ```
#
# 2024-10-11 10:20:19 [INFO] Executing Step 2: CodeCleaning
# 2024-10-11 10:20:20 [INFO]
# Code running:
# ```
# def find_outliers(df):
#     height_mean = df['Height'].mean()
#     height_std = df['Height'].std()
#     outlier_df = df[(df['Height'] < height_mean - 3 * height_std) | (df['Height'] > height_mean + 3 * height_std)]
#     return {'type': 'dataframe', 'value': outlier_df}
#
#
# outliers = find_outliers(dfs[0])
# print(outliers)
#         ```
# 2024-10-11 10:20:20 [ERROR] Unable to extract filters for passed code
# {'type': 'dataframe', 'value':      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 676    5.0                       4.0    2.0   2.0      1.0              2.0
#
#      Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 676      2.0  1.0   2.0                2.0  ...  20.0    62.0    55.0
#
#      Number of siblings  Gender  Left - right handed                Education  \
# 676                 2.0  female         right handed  college/bachelor degree
#
#      Only child  Village - town  House - block of flats
# 676          no            city          house/bungalow
#
# [1 rows x 150 columns]}
# 2024-10-11 10:20:20 [ERROR] Failed with error: Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# 2024-10-11 10:20:20 [ERROR] Pipeline failed on step 6: No result returned
# Traceback (most recent call last):
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 335, in run
#     ).run(input)
#       ^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#                   ^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 113, in execute
#     raise e
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kocha\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nNo result returned\n'
